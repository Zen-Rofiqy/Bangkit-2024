# %% [markdown]
# ### How to Create Raincloud Plots in Python
# In this python data visualization tutorial we are going to learn about a new way to visualize data; the raincloud plot. This type of plot combines the boxplot, violin plot, & the scatter plot into one visualization. This [tutorial](https://youtu.be/uFDdzTjn190) requires that you have ptitprince and it's dependencies installed. Let's start by installing it using pip:
#
# ```
# pip install ptitprince
# ```

# %% [markdown]
# ### Creating a Raincloud Plot using Ptitprince
# Now that we have ptitprince installed we can start by importing pandas as pd and ptitprince as pt:

# %%
# %matplotlib inline
import pandas as pd
import ptitprince as pt
import matplotlib.pyplot as plt


# Ignore Warnings
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %% [markdown]
# ### Reading a CSV file from an URL
# Next we are going to read a CSV file from an url. We use Pandas read_csv to do this and if you are looking for a good pandas read_csv tutorial, check the link in the description below.

# %%
df = pd.read_csv('https://vincentarelbundock.github.io/Rdatasets/csv/datasets/iris.csv')
df.head()
# Out:
#    rownames  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0         1           5.1          3.5           1.4          0.2  setosa
# 1         2           4.9          3.0           1.4          0.2  setosa
# 2         3           4.7          3.2           1.3          0.2  setosa
# 3         4           4.6          3.1           1.5          0.2  setosa
# 4         5           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ### Raincloud Data Visualization in Python
# Now, we are ready to create our first Raincloud Plot using Python!

# %%
fig = plt.figure(figsize=(12,8), dpi= 100, facecolor='w', edgecolor='k')
ax = fig.add_subplot(111)

ax = pt.RainCloud(x = 'Species', y = 'Sepal.Length', 
                  data = df, 
                  width_viol = .8,
                  width_box = .4,
                  figsize = (12, 8), orient = 'h',
                  move = .0, ax=ax)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 4
#       1 fig = plt.figure(figsize=(12,8), dpi= 100, facecolor='w', edgecolor='k')
#       2 ax = fig.add_subplot(111)
# ----> 4 ax = pt.RainCloud(x = 'Species', y = 'Sepal.Length',
#       5                   data = df,
#       6                   width_viol = .8,
#       7                   width_box = .4,
#       8                   figsize = (12, 8), orient = 'h',
#       9                   move = .0, ax=ax)
#
# File c:\Users\Fathan\Documents\Obsidian Vault\2. Kuliah\Smt 6\@ Bangkit 2024\myenv\lib\site-packages\ptitprince\PtitPrince.py:744, in RainCloud(x, y, hue, data, order, hue_order, orient, width_viol, width_box, palette, bw, linewidth, cut, scale, jitter, move, offset, point_size, ax, pointplot, alpha, dodge, linecolor, **kwargs)
#     741         kwcloud[key] = value
#     743 # Draw cloud/half-violin
# --> 744 half_violinplot(x = x, y = y, hue = hue, data = data,
#     745                 order = order, hue_order = hue_order,
#     746                 orient = orient, width = width_viol,
#     747                 inner = None, palette = palette, bw = bw,  linewidth = linewidth,
#     748                 cut = cut, scale = scale, split = split, offset = offset, ax = ax, **kwcloud)
#     750 # Draw umberella/boxplot
#     751 sns.boxplot   (x = x, y = y, hue = hue, data = data, orient = orient, width = width_box,
#     752                      order = order, hue_order = hue_order,
#     753                      color = boxcolor, showcaps = True, boxprops = boxprops,
#     754                      palette = palette, dodge = dodge, ax =ax, **kwbox)
#
# File c:\Users\Fathan\Documents\Obsidian Vault\2. Kuliah\Smt 6\@ Bangkit 2024\myenv\lib\site-packages\ptitprince\PtitPrince.py:672, in half_violinplot(x, y, hue, data, order, hue_order, bw, cut, scale, scale_hue, gridsize, width, inner, split, dodge, orient, linewidth, color, palette, saturation, ax, offset, **kwargs)
#     669 if ax is None:
#     670     ax = plt.gca()
# --> 672 plotter.plot(ax, kwargs)
#     673 return ax
#
# File c:\Users\Fathan\Documents\Obsidian Vault\2. Kuliah\Smt 6\@ Bangkit 2024\myenv\lib\site-packages\ptitprince\PtitPrince.py:624, in _Half_ViolinPlotter.plot(self, ax, kws)
#     622 def plot(self, ax, kws):
#     623     """Make the violin plot."""
# --> 624     self.draw_violins(ax, kws)
#     625     self.annotate_axes(ax)
#     626     if self.orient == "h":
#
# File c:\Users\Fathan\Documents\Obsidian Vault\2. Kuliah\Smt 6\@ Bangkit 2024\myenv\lib\site-packages\ptitprince\PtitPrince.py:367, in _Half_ViolinPlotter.draw_violins(self, ax, kws)
#     365 # Draw the violin for this group
#     366 grid = np.ones(self.gridsize) * i
# --> 367 fill_func(support,
#     368           -self.offset + grid - density * self.dwidth,
#     369           -self.offset + grid,
#     370           facecolor=self.colors[i],
#     371           **kws)
#     373 # Draw the interior representation of the data
#     374 if self.inner is None:
#
# File c:\Users\Fathan\Documents\Obsidian Vault\2. Kuliah\Smt 6\@ Bangkit 2024\myenv\lib\site-packages\matplotlib\__init__.py:1478, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1475 @functools.wraps(func)
#    1476 def inner(ax, *args, data=None, **kwargs):
#    1477     if data is None:
# -> 1478         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1480     bound = new_sig.bind(ax, *args, **kwargs)
#    1481     auto_label = (bound.arguments.get(label_namer)
#    1482                   or bound.kwargs.get(label_namer))
#
# File c:\Users\Fathan\Documents\Obsidian Vault\2. Kuliah\Smt 6\@ Bangkit 2024\myenv\lib\site-packages\matplotlib\axes\_axes.py:5512, in Axes.fill_between(self, x, y1, y2, where, interpolate, step, **kwargs)
#    5510 def fill_between(self, x, y1, y2=0, where=None, interpolate=False,
#    5511                  step=None, **kwargs):
# -> 5512     return self._fill_between_x_or_y(
#    5513         "x", x, y1, y2,
#    5514         where=where, interpolate=interpolate, step=step, **kwargs)
#
# File c:\Users\Fathan\Documents\Obsidian Vault\2. Kuliah\Smt 6\@ Bangkit 2024\myenv\lib\site-packages\matplotlib\axes\_axes.py:5493, in Axes._fill_between_x_or_y(self, ind_dir, ind, dep1, dep2, where, interpolate, step, **kwargs)
#    5489         pts = pts[:, ::-1]
#    5491     polys.append(pts)
# -> 5493 collection = mcoll.PolyCollection(polys, **kwargs)
#    5495 # now update the datalim and autoscale
#    5496 pts = np.vstack([np.hstack([ind[where, None], dep1[where, None]]),
#    5497                  np.hstack([ind[where, None], dep2[where, None]])])
#
# File c:\Users\Fathan\Documents\Obsidian Vault\2. Kuliah\Smt 6\@ Bangkit 2024\myenv\lib\site-packages\matplotlib\collections.py:1198, in PolyCollection.__init__(self, verts, sizes, closed, **kwargs)
#    1178 def __init__(self, verts, sizes=None, *, closed=True, **kwargs):
#    1179     """
#    1180     Parameters
#    1181     ----------
#    (...)
#    1196         Forwarded to `.Collection`.
#    1197     """
# -> 1198     super().__init__(**kwargs)
#    1199     self.set_sizes(sizes)
#    1200     self.set_verts(verts, closed)
#
# File c:\Users\Fathan\Documents\Obsidian Vault\2. Kuliah\Smt 6\@ Bangkit 2024\myenv\lib\site-packages\matplotlib\collections.py:203, in Collection.__init__(self, edgecolors, facecolors, linewidths, linestyles, capstyle, joinstyle, antialiaseds, offsets, offset_transform, norm, cmap, pickradius, hatch, urls, zorder, **kwargs)
#     200 self._offset_transform = offset_transform
#     202 self._path_effects = None
# --> 203 self._internal_update(kwargs)
#     204 self._paths = None
#
# File c:\Users\Fathan\Documents\Obsidian Vault\2. Kuliah\Smt 6\@ Bangkit 2024\myenv\lib\site-packages\matplotlib\artist.py:1219, in Artist._internal_update(self, kwargs)
#    1212 def _internal_update(self, kwargs):
#    1213     """
#    1214     Update artist properties without prenormalizing them, but generating
#    1215     errors as if calling `set`.
#    1216
#    1217     The lack of prenormalization is to maintain backcompatibility.
#    1218     """
# -> 1219     return self._update_props(
#    1220         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1221         "{prop_name!r}")
#
# File c:\Users\Fathan\Documents\Obsidian Vault\2. Kuliah\Smt 6\@ Bangkit 2024\myenv\lib\site-packages\matplotlib\artist.py:1193, in Artist._update_props(self, props, errfmt)
#    1191             func = getattr(self, f"set_{k}", None)
#    1192             if not callable(func):
# -> 1193                 raise AttributeError(
#    1194                     errfmt.format(cls=type(self), prop_name=k))
#    1195             ret.append(func(v))
#    1196 if ret:
#
# AttributeError: PolyCollection.set() got an unexpected keyword argument 'figsize'

# %% [markdown]
# ### Adding a Pointplot Connecting the Means
# We can also add a Pointplot connecting the means by changing the "pointplot" argument to True

# %%
ax = pt.RainCloud(x = 'Species', y = 'Sepal.Length', 
                  data = df,
                  pointplot = True,
                  width_viol = .8,
                  width_box = .4,
                  figsize = (12, 8), orient = 'h',
                  move = .0)
